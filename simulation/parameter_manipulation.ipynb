# %%
# %load_ext autoreload
# %autoreload 2

# import data and packages

import pandas as pd
import numpy as np
from helper_functions import test_model, test_bayesian_networks_model

data = pd.read_pickle('input_data.pickle')

# %%
import pandas as pd
from math import ceil, floor
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier


def k_fold_cross_validation_knn(k, data_, k_):

    data = data_.reset_index()

    i = len(data) / k

    test_data = data[:floor(i)]
    learn_data = data[floor(i):]
    
    model = KNeighborsClassifier(n_neighbors=k_)

    df = pd.DataFrame(columns=["k", "Brier score", 
                               "precision", "recall", "F1", 
                               "confusion_matrix", "profit", "modified Brier score"])

    index = 0

    brier_score, precision, recall, F1, confusion_matrix, profit, modified_brier_score = \
            test_model(learn_data, test_data, model)

    new_line = pd.DataFrame.from_dict({
            "k": [float(k_)],
            "Brier score": [brier_score], 
            "precision": [precision], 
            "recall": [recall], 
            "F1": [F1], 
            "confusion_matrix": [confusion_matrix], 
            "profit": [profit],
            "modified Brier score": [modified_brier_score]
        })

    df = pd.concat([df, new_line])

    index += 1


    for j in range(1, k - 1):
        bound1 = ceil((j * i))
        bound2 = floor((j + 1) * i)

        test_data = data[bound1:bound2]

        learn_data_1 = data[:bound1]
        learn_data_2 = data[bound2:]
        learn_data = pd.concat([learn_data_1, learn_data_2])

        brier_score, precision, recall, F1, confusion_matrix, profit, modified_brier_score = \
            test_model(learn_data, test_data, model)

        new_line = pd.DataFrame.from_dict({
            "k": [float(k_)],
            "Brier score": [brier_score], 
            "precision": [precision], 
            "recall": [recall], 
            "F1": [F1], 
            "confusion_matrix": [confusion_matrix], 
            "profit": [profit],
            "modified Brier score": [modified_brier_score]
        })

        df = pd.concat([df, new_line])

        index += 1


    test_data = data[ceil(((k - 1) * i)):]
    learn_data = data[:ceil(((k - 1) * i))]
    
    brier_score, precision, recall, F1, confusion_matrix, profit, modified_brier_score = \
        test_model(learn_data, test_data, model)

    new_line = pd.DataFrame.from_dict({
        "k": [float(k_)],
        "Brier score": [brier_score], 
        "precision": [precision], 
        "recall": [recall], 
        "F1": [F1], 
        "confusion_matrix": [confusion_matrix], 
        "profit": [profit],
        "modified Brier score": [modified_brier_score]
    })

    df = pd.concat([df, new_line])

    index += 1

    return df.mean(numeric_only=True)


df = k_fold_cross_validation_knn(10, data, 1)

df
# Out:
# k                         1.000000
# Brier score             398.400000
# precision                 0.506022
# recall                    0.497605
# F1                        0.500730
# profit                   -0.059432
# modified Brier score    211.029723
# dtype: float64

# %%
values = []

for i in range(5,130):
    values.append(k_fold_cross_validation_knn(10, data, i))
    print(f"{i} / 200 \t finished")

data = pd.DataFrame(values)

data
# Out:
# 5 / 200 	 finished
# 6 / 200 	 finished
# 7 / 200 	 finished
# 8 / 200 	 finished
# 9 / 200 	 finished
# 10 / 200 	 finished
# 11 / 200 	 finished
# 12 / 200 	 finished
# 13 / 200 	 finished
# 14 / 200 	 finished
# 15 / 200 	 finished
# 16 / 200 	 finished
# 17 / 200 	 finished
# 18 / 200 	 finished
# 19 / 200 	 finished
# 20 / 200 	 finished
# 21 / 200 	 finished
# 22 / 200 	 finished
# 23 / 200 	 finished
# 24 / 200 	 finished
# 25 / 200 	 finished
# 26 / 200 	 finished
# 27 / 200 	 finished
# 28 / 200 	 finished
# 29 / 200 	 finished
# 30 / 200 	 finished
# 31 / 200 	 finished
# 32 / 200 	 finished
# 33 / 200 	 finished
# 34 / 200 	 finished
# 35 / 200 	 finished
# 36 / 200 	 finished
# 37 / 200 	 finished
# 38 / 200 	 finished
# 39 / 200 	 finished
# 40 / 200 	 finished
# 41 / 200 	 finished
# 42 / 200 	 finished
# 43 / 200 	 finished
# 44 / 200 	 finished
# 45 / 200 	 finished
# 46 / 200 	 finished
# 47 / 200 	 finished
# 48 / 200 	 finished
# 49 / 200 	 finished
# 50 / 200 	 finished
# 51 / 200 	 finished
# 52 / 200 	 finished
# 53 / 200 	 finished
# 54 / 200 	 finished
# 55 / 200 	 finished
# 56 / 200 	 finished
# 57 / 200 	 finished
# 58 / 200 	 finished
# 59 / 200 	 finished
# 60 / 200 	 finished
# 61 / 200 	 finished
# 62 / 200 	 finished
# 63 / 200 	 finished
# 64 / 200 	 finished
# 65 / 200 	 finished
# 66 / 200 	 finished
# 67 / 200 	 finished
# 68 / 200 	 finished
# 69 / 200 	 finished
# 70 / 200 	 finished
# 71 / 200 	 finished
# 72 / 200 	 finished
# 73 / 200 	 finished
# 74 / 200 	 finished
# 75 / 200 	 finished
# 76 / 200 	 finished
# 77 / 200 	 finished
# 78 / 200 	 finished
# 79 / 200 	 finished
# 80 / 200 	 finished
# 81 / 200 	 finished
# 82 / 200 	 finished
# 83 / 200 	 finished
# 84 / 200 	 finished
# 85 / 200 	 finished
# 86 / 200 	 finished
# 87 / 200 	 finished
# 88 / 200 	 finished
# 89 / 200 	 finished
# 90 / 200 	 finished
# 91 / 200 	 finished
# 92 / 200 	 finished
# 93 / 200 	 finished
# 94 / 200 	 finished
# 95 / 200 	 finished
# 96 / 200 	 finished
# 97 / 200 	 finished
# 98 / 200 	 finished
# 99 / 200 	 finished
# 100 / 200 	 finished
# 101 / 200 	 finished
# 102 / 200 	 finished
# 103 / 200 	 finished
# 104 / 200 	 finished
# 105 / 200 	 finished
# 106 / 200 	 finished
# 107 / 200 	 finished
# 108 / 200 	 finished
# 109 / 200 	 finished
# 110 / 200 	 finished
# 111 / 200 	 finished
# 112 / 200 	 finished
# 113 / 200 	 finished
# 114 / 200 	 finished
# 115 / 200 	 finished
# 116 / 200 	 finished
# 117 / 200 	 finished
# 118 / 200 	 finished
# 119 / 200 	 finished
# 120 / 200 	 finished
# 121 / 200 	 finished
# 122 / 200 	 finished
# 123 / 200 	 finished
# 124 / 200 	 finished
# 125 / 200 	 finished
# 126 / 200 	 finished
# 127 / 200 	 finished
# 128 / 200 	 finished
# 129 / 200 	 finished
#          k  Brier score  precision    recall        F1    profit  \
# 0      5.0   243.136000   0.502543  0.694067  0.582195 -0.120213
# 1      6.0   234.533333   0.506489  0.703458  0.588476 -0.104134
# 2      7.0   229.624490   0.511545  0.690968  0.587249 -0.083076
# 3      8.0   225.003125   0.513925  0.731571  0.603020 -0.086696
# 4      9.0   223.049383   0.507296  0.716605  0.593312 -0.066440
# ..     ...          ...        ...       ...       ...       ...
# 120  125.0   203.302797   0.494614  0.900828  0.637593 -0.085780
# 121  126.0   203.236042   0.494143  0.898897  0.636630 -0.072875
# 122  127.0   203.199913   0.495000  0.900010  0.637727 -0.073984
# 123  128.0   203.270129   0.495655  0.904792  0.639398 -0.081757
# 124  129.0   203.303527   0.496097  0.904574  0.639790 -0.083895
#
#      modified Brier score
# 0               52.697455
# 1               45.374383
# 2               40.875115
# 3               37.524888
# 4               34.974867
# ..                    ...
# 120             15.985063
# 121             15.981820
# 122             15.978155
# 123             15.987255
# 124             15.986929
#
# [125 rows x 7 columns]

# %%
data.to_csv('../analysis/tables/kNN_analysis.csv')
data.to_pickle('../analysis/tables/kNN_analysis.pickle')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 data.to_csv('../analysis/tables/kNN_analysis.csv')
#       2 data.to_pickle('../analysis/tables/kNN_analysis.pickle')
#
# NameError: name 'data' is not defined

# %%
# %load_ext autoreload
# %autoreload 2

# import data and packages

import pandas as pd
import numpy as np
from helper_functions import test_model, test_bayesian_networks_model

data = pd.read_pickle('input_data.pickle')

# %%
data
# Out:
#           result  odds_home  odds_draw  odds_away points_home points_away  \
# index
# 50.0    home win       1.20       6.00      15.00          15           3
# 51.0    home win       1.13       8.00      19.00          15           6
# 52.0        draw       2.10       3.30       3.50           6           4
# 53.0    home win       1.67       3.75       5.00           5           3
# 54.0    away win      10.00       5.50       1.29           3          13
# ...          ...        ...        ...        ...         ...         ...
# 3415.0      draw       1.44       4.33       7.50           8           2
# 3416.0  away win       3.30       3.40       2.20           3           7
# 3417.0  away win       2.10       4.00       3.00          10           7
# 3418.0  home win       2.50       3.30       2.87           7          10
# 3419.0  away win       2.62       3.30       2.70           7           8
#
#        goals_scored_home goals_scored_away goals_conceded_home  \
# index
# 50.0                  16                 4                   4
# 51.0                  18                 4                   4
# 52.0                   4                 3                  10
# 53.0                   7                10                   4
# 54.0                   4                12                   8
# ...                  ...               ...                 ...
# 3415.0                 8                 3                   5
# 3416.0                 4                 7                   8
# 3417.0                 7                10                   4
# 3418.0                 6                 7                   5
# 3419.0                 7                 4                   5
#
#        goals_conceded_away shots_given_home shots_given_away  \
# index
# 50.0                    10               81               60
# 51.0                     3               90               60
# 52.0                     6               47               55
# 53.0                    13               63               60
# 54.0                     5               58              110
# ...                    ...              ...              ...
# 3415.0                   9               62               48
# 3416.0                  10               53               51
# 3417.0                   6               61               63
# 3418.0                   3               57               52
# 3419.0                   3               61               70
#
#        shots_conceded_home shots_conceded_away corners_difference_home  \
# index
# 50.0                    50                  57                      24
# 51.0                    50                  67                      22
# 52.0                    89                  71                      -5
# 53.0                    61                  79                     -21
# 54.0                    47                  57                      13
# ...                    ...                 ...                     ...
# 3415.0                  72                  81                      -9
# 3416.0                  66                  72                      -3
# 3417.0                  45                  51                       9
# 3418.0                  61                  60                      -5
# 3419.0                  64                  50                     -13
#
#        corners_difference_away
# index
# 50.0                        -1
# 51.0                        -4
# 52.0                       -10
# 53.0                       -13
# 54.0                         1
# ...                        ...
# 3415.0                     -15
# 3416.0                     -10
# 3417.0                       1
# 3418.0                      10
# 3419.0                       2
#
# [3316 rows x 16 columns]

# %%
# MLP analysis

import pandas as pd
from math import ceil, floor
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier


def k_fold_cross_validation_mlp_layers(k, data_, k_):

    data = data_.reset_index()

    i = len(data) / k

    test_data = data[:floor(i)]
    learn_data = data[floor(i):]

    sizes = (20,) * k_

    model = MLPClassifier(hidden_layer_sizes=sizes, max_iter=1000)

    df = pd.DataFrame(columns=["k", "Brier score", 
                               "precision", "recall", "F1", 
                               "confusion_matrix", "profit", "modified Brier score"])

    index = 0

    brier_score, precision, recall, F1, confusion_matrix, profit, modified_brier_score = \
            test_model(learn_data, test_data, model)

    new_line = pd.DataFrame.from_dict({
            "k": [float(k_)],
            "Brier score": [brier_score], 
            "precision": [precision], 
            "recall": [recall], 
            "F1": [F1], 
            "confusion_matrix": [confusion_matrix], 
            "profit": [profit],
            "modified Brier score": [modified_brier_score]
        })

    df = pd.concat([df, new_line])

    index += 1


    for j in range(1, k - 1):
        bound1 = ceil((j * i))
        bound2 = floor((j + 1) * i)

        test_data = data[bound1:bound2]

        learn_data_1 = data[:bound1]
        learn_data_2 = data[bound2:]
        learn_data = pd.concat([learn_data_1, learn_data_2])

        brier_score, precision, recall, F1, confusion_matrix, profit, modified_brier_score = \
            test_model(learn_data, test_data, model)

        new_line = pd.DataFrame.from_dict({
            "k": [float(k_)],
            "Brier score": [brier_score], 
            "precision": [precision], 
            "recall": [recall], 
            "F1": [F1], 
            "confusion_matrix": [confusion_matrix], 
            "profit": [profit],
            "modified Brier score": [modified_brier_score]
        })

        df = pd.concat([df, new_line])

        index += 1


    test_data = data[ceil(((k - 1) * i)):]
    learn_data = data[:ceil(((k - 1) * i))]
    
    brier_score, precision, recall, F1, confusion_matrix, profit, modified_brier_score = \
        test_model(learn_data, test_data, model)

    new_line = pd.DataFrame.from_dict({
        "k": [float(k_)],
        "Brier score": [brier_score], 
        "precision": [precision], 
        "recall": [recall], 
        "F1": [F1], 
        "confusion_matrix": [confusion_matrix], 
        "profit": [profit],
        "modified Brier score": [modified_brier_score]
    })

    df = pd.concat([df, new_line])

    index += 1

    return df.mean(numeric_only=True)


df = k_fold_cross_validation_mlp_layers(10, data, 1)

df
# Out:
# k                         1.000000
# Brier score             203.988759
# precision                 0.544511
# recall                    0.753733
# F1                        0.622059
# profit                   -0.117496
# modified Brier score     16.420719
# dtype: float64

# %%
values = []

for i in range(1,10):
    values.append(k_fold_cross_validation_mlp_layers(10, data, i))
    print(f"{i} / 20 \t finished")

data_mlp = pd.DataFrame(values)

data_mlp
# Out:
# 1 / 20 	 finished
# 2 / 20 	 finished
# 3 / 20 	 finished
# 4 / 20 	 finished
# 5 / 20 	 finished
# 6 / 20 	 finished
# 7 / 20 	 finished
# 8 / 20 	 finished
# 9 / 20 	 finished
#      k  Brier score  precision    recall        F1    profit  \
# 0  1.0   204.304675   0.522472  0.858316  0.646637 -0.085696
# 1  2.0   201.927014   0.523693  0.852251  0.646955 -0.082827
# 2  3.0   204.943537   0.558742  0.714839  0.617478 -0.110672
# 3  4.0   206.828739   0.513309  0.817087  0.627490 -0.087602
# 4  5.0   211.851823   0.526548  0.755247  0.617722 -0.095387
# 5  6.0   211.049758   0.531462  0.759969  0.621150 -0.075247
# 6  7.0   221.812366   0.520092  0.718897  0.600550 -0.139763
# 7  8.0   224.212136   0.517601  0.695753  0.590370 -0.115528
# 8  9.0   222.500287   0.523975  0.702819  0.598722 -0.083261
#
#    modified Brier score
# 0             16.303933
# 1             14.821909
# 2             16.281780
# 3             17.153391
# 4             22.827557
# 5             24.069515
# 6             32.258361
# 7             34.384430
# 8             34.535741

# %%
data_mlp.to_csv('../analysis/tables/MLP_analysis_sizes.csv')
data_mlp.to_pickle('../analysis/tables/MLP_analysis_sizes.pickle')

# %%
# MLP analysis

import pandas as pd
from math import ceil, floor
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier


def k_fold_cross_validation_mlp_neurons(k, data_, k_):

    data = data_.reset_index()

    i = len(data) / k

    test_data = data[:floor(i)]
    learn_data = data[floor(i):]

    sizes = (k_,)

    model = MLPClassifier(hidden_layer_sizes=sizes, max_iter=1000)

    df = pd.DataFrame(columns=["k", "Brier score", 
                               "precision", "recall", "F1", 
                               "confusion_matrix", "profit", "modified Brier score"])

    index = 0

    brier_score, precision, recall, F1, confusion_matrix, profit, modified_brier_score = \
            test_model(learn_data, test_data, model)

    new_line = pd.DataFrame.from_dict({
            "k": [float(k_)],
            "Brier score": [brier_score], 
            "precision": [precision], 
            "recall": [recall], 
            "F1": [F1], 
            "confusion_matrix": [confusion_matrix], 
            "profit": [profit],
            "modified Brier score": [modified_brier_score]
        })

    df = pd.concat([df, new_line])

    index += 1


    for j in range(1, k - 1):
        bound1 = ceil((j * i))
        bound2 = floor((j + 1) * i)

        test_data = data[bound1:bound2]

        learn_data_1 = data[:bound1]
        learn_data_2 = data[bound2:]
        learn_data = pd.concat([learn_data_1, learn_data_2])

        brier_score, precision, recall, F1, confusion_matrix, profit, modified_brier_score = \
            test_model(learn_data, test_data, model)

        new_line = pd.DataFrame.from_dict({
            "k": [float(k_)],
            "Brier score": [brier_score], 
            "precision": [precision], 
            "recall": [recall], 
            "F1": [F1], 
            "confusion_matrix": [confusion_matrix], 
            "profit": [profit],
            "modified Brier score": [modified_brier_score]
        })

        df = pd.concat([df, new_line])

        index += 1


    test_data = data[ceil(((k - 1) * i)):]
    learn_data = data[:ceil(((k - 1) * i))]
    
    brier_score, precision, recall, F1, confusion_matrix, profit, modified_brier_score = \
        test_model(learn_data, test_data, model)

    new_line = pd.DataFrame.from_dict({
        "k": [float(k_)],
        "Brier score": [brier_score], 
        "precision": [precision], 
        "recall": [recall], 
        "F1": [F1], 
        "confusion_matrix": [confusion_matrix], 
        "profit": [profit],
        "modified Brier score": [modified_brier_score]
    })

    df = pd.concat([df, new_line])

    index += 1

    return df.mean(numeric_only=True)


df = k_fold_cross_validation_mlp_neurons(10, data, 1)

df
# Out:
# k                         1.000000
# Brier score             212.719807
# precision                 0.459029
# recall                    1.000000
# F1                        0.628859
# profit                   -0.105844
# modified Brier score     25.888669
# dtype: float64

# %%
values = []

for i in range(10,340, 30):
    values.append(k_fold_cross_validation_mlp_neurons(10, data, i))
    print(f"{i} / 20 \t finished")

data_mlp_neurons = pd.DataFrame(values)

data_mlp_neurons
# Out:
# 10 / 20 	 finished
# 40 / 20 	 finished
# 70 / 20 	 finished
# 100 / 20 	 finished
# 130 / 20 	 finished
# 160 / 20 	 finished
# 190 / 20 	 finished
# 220 / 20 	 finished
# 250 / 20 	 finished
# 280 / 20 	 finished
# 310 / 20 	 finished
#         k  Brier score  precision    recall        F1    profit  \
# 0    10.0   203.965984   0.527988  0.805435  0.635347 -0.103048
# 1    40.0   205.282804   0.516935  0.819272  0.632444 -0.088613
# 2    70.0   205.482310   0.542721  0.721390  0.613029 -0.095206
# 3   100.0   208.218211   0.522087  0.787382  0.623202 -0.102677
# 4   130.0   209.744546   0.552367  0.682935  0.599423 -0.096674
# 5   160.0   212.816095   0.563997  0.652813  0.565617 -0.122335
# 6   190.0   205.861871   0.533621  0.772989  0.622325 -0.088958
# 7   220.0   209.047189   0.521991  0.793252  0.624792 -0.086590
# 8   250.0   208.785757   0.524450  0.774496  0.616107 -0.081250
# 9   280.0   213.829608   0.516963  0.748079  0.602725 -0.082521
# 10  310.0   213.609574   0.559782  0.621796  0.569810 -0.088973
#
#     modified Brier score
# 0              15.623840
# 1              16.931823
# 2              18.984507
# 3              19.115221
# 4              21.448234
# 5              23.936578
# 6              19.395876
# 7              20.215117
# 8              20.372620
# 9              23.288305
# 10             25.435367

# %%
data_mlp_neurons.to_csv('../analysis/tables/MLP_analysis_neurons.csv')
data_mlp_neurons.to_pickle('../analysis/tables/MLP_analysis_neurons.pickle')

# %%
# Learning data size manipulation

# MLP analysis

import pandas as pd
from math import ceil, floor
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier


def test_in_regard_to_data_size(learn_data, test_data):
     
    df = pd.DataFrame(columns=["data size", "Brier score", 
                               "precision", "recall", "F1", 
                               "confusion_matrix", "profit", "modified Brier score"])

    brier_score, precision, recall, F1, confusion_matrix, profit, modified_brier_score = \
            test_model(learn_data, test_data, GaussianNB())

    new_line = pd.DataFrame.from_dict({
            "data size": [float(len(learn_data))],
            "Brier score": [brier_score], 
            "precision": [precision], 
            "recall": [recall], 
            "F1": [F1], 
            "confusion_matrix": [confusion_matrix], 
            "profit": [profit],
            "modified Brier score": [modified_brier_score]
        })

    df = pd.concat([df, new_line])

    return df.mean(numeric_only=True)

# %%
test_data = data[:563]
test_data = test_data.reset_index()

rest_of_data = data[563:]
len(rest_of_data)
# Out:
# 2817

# %%
values = []


for i in range(100, 2800, 10):
    j = 563 + i

    learn_data = rest_of_data[:j]
    learn_data = learn_data.reset_index()
    values.append(test_in_regard_to_data_size(learn_data, test_data))
    print(f"{i} / 2800 \t finished")

data_size = pd.DataFrame(values)

data_size
# Out:
# 100 / 2800 	 finished
# 110 / 2800 	 finished
# 120 / 2800 	 finished
# 130 / 2800 	 finished
# 140 / 2800 	 finished
# 150 / 2800 	 finished
# 160 / 2800 	 finished
# 170 / 2800 	 finished
# 180 / 2800 	 finished
# 190 / 2800 	 finished
# 200 / 2800 	 finished
# 210 / 2800 	 finished
# 220 / 2800 	 finished
# 230 / 2800 	 finished
# 240 / 2800 	 finished
# 250 / 2800 	 finished
# 260 / 2800 	 finished
# 270 / 2800 	 finished
# 280 / 2800 	 finished
# 290 / 2800 	 finished
# 300 / 2800 	 finished
# 310 / 2800 	 finished
# 320 / 2800 	 finished
# 330 / 2800 	 finished
# 340 / 2800 	 finished
# 350 / 2800 	 finished
# 360 / 2800 	 finished
# 370 / 2800 	 finished
# 380 / 2800 	 finished
# 390 / 2800 	 finished
# 400 / 2800 	 finished
# 410 / 2800 	 finished
# 420 / 2800 	 finished
# 430 / 2800 	 finished
# 440 / 2800 	 finished
# 450 / 2800 	 finished
# 460 / 2800 	 finished
# 470 / 2800 	 finished
# 480 / 2800 	 finished
# 490 / 2800 	 finished
# 500 / 2800 	 finished
# 510 / 2800 	 finished
# 520 / 2800 	 finished
# 530 / 2800 	 finished
# 540 / 2800 	 finished
# 550 / 2800 	 finished
# 560 / 2800 	 finished
# 570 / 2800 	 finished
# 580 / 2800 	 finished
# 590 / 2800 	 finished
# 600 / 2800 	 finished
# 610 / 2800 	 finished
# 620 / 2800 	 finished
# 630 / 2800 	 finished
# 640 / 2800 	 finished
# 650 / 2800 	 finished
# 660 / 2800 	 finished
# 670 / 2800 	 finished
# 680 / 2800 	 finished
# 690 / 2800 	 finished
# 700 / 2800 	 finished
# 710 / 2800 	 finished
# 720 / 2800 	 finished
# 730 / 2800 	 finished
# 740 / 2800 	 finished
# 750 / 2800 	 finished
# 760 / 2800 	 finished
# 770 / 2800 	 finished
# 780 / 2800 	 finished
# 790 / 2800 	 finished
# 800 / 2800 	 finished
# 810 / 2800 	 finished
# 820 / 2800 	 finished
# 830 / 2800 	 finished
# 840 / 2800 	 finished
# 850 / 2800 	 finished
# 860 / 2800 	 finished
# 870 / 2800 	 finished
# 880 / 2800 	 finished
# 890 / 2800 	 finished
# 900 / 2800 	 finished
# 910 / 2800 	 finished
# 920 / 2800 	 finished
# 930 / 2800 	 finished
# 940 / 2800 	 finished
# 950 / 2800 	 finished
# 960 / 2800 	 finished
# 970 / 2800 	 finished
# 980 / 2800 	 finished
# 990 / 2800 	 finished
# 1000 / 2800 	 finished
# 1010 / 2800 	 finished
# 1020 / 2800 	 finished
# 1030 / 2800 	 finished
# 1040 / 2800 	 finished
# 1050 / 2800 	 finished
# 1060 / 2800 	 finished
# 1070 / 2800 	 finished
# 1080 / 2800 	 finished
# 1090 / 2800 	 finished
# 1100 / 2800 	 finished
# 1110 / 2800 	 finished
# 1120 / 2800 	 finished
# 1130 / 2800 	 finished
# 1140 / 2800 	 finished
# 1150 / 2800 	 finished
# 1160 / 2800 	 finished
# 1170 / 2800 	 finished
# 1180 / 2800 	 finished
# 1190 / 2800 	 finished
# 1200 / 2800 	 finished
# 1210 / 2800 	 finished
# 1220 / 2800 	 finished
# 1230 / 2800 	 finished
# 1240 / 2800 	 finished
# 1250 / 2800 	 finished
# 1260 / 2800 	 finished
# 1270 / 2800 	 finished
# 1280 / 2800 	 finished
# 1290 / 2800 	 finished
# 1300 / 2800 	 finished
# 1310 / 2800 	 finished
# 1320 / 2800 	 finished
# 1330 / 2800 	 finished
# 1340 / 2800 	 finished
# 1350 / 2800 	 finished
# 1360 / 2800 	 finished
# 1370 / 2800 	 finished
# 1380 / 2800 	 finished
# 1390 / 2800 	 finished
# 1400 / 2800 	 finished
# 1410 / 2800 	 finished
# 1420 / 2800 	 finished
# 1430 / 2800 	 finished
# 1440 / 2800 	 finished
# 1450 / 2800 	 finished
# 1460 / 2800 	 finished
# 1470 / 2800 	 finished
# 1480 / 2800 	 finished
# 1490 / 2800 	 finished
# 1500 / 2800 	 finished
# 1510 / 2800 	 finished
# 1520 / 2800 	 finished
# 1530 / 2800 	 finished
# 1540 / 2800 	 finished
# 1550 / 2800 	 finished
# 1560 / 2800 	 finished
# 1570 / 2800 	 finished
# 1580 / 2800 	 finished
# 1590 / 2800 	 finished
# 1600 / 2800 	 finished
# 1610 / 2800 	 finished
# 1620 / 2800 	 finished
# 1630 / 2800 	 finished
# 1640 / 2800 	 finished
# 1650 / 2800 	 finished
# 1660 / 2800 	 finished
# 1670 / 2800 	 finished
# 1680 / 2800 	 finished
# 1690 / 2800 	 finished
# 1700 / 2800 	 finished
# 1710 / 2800 	 finished
# 1720 / 2800 	 finished
# 1730 / 2800 	 finished
# 1740 / 2800 	 finished
# 1750 / 2800 	 finished
# 1760 / 2800 	 finished
# 1770 / 2800 	 finished
# 1780 / 2800 	 finished
# 1790 / 2800 	 finished
# 1800 / 2800 	 finished
# 1810 / 2800 	 finished
# 1820 / 2800 	 finished
# 1830 / 2800 	 finished
# 1840 / 2800 	 finished
# 1850 / 2800 	 finished
# 1860 / 2800 	 finished
# 1870 / 2800 	 finished
# 1880 / 2800 	 finished
# 1890 / 2800 	 finished
# 1900 / 2800 	 finished
# 1910 / 2800 	 finished
# 1920 / 2800 	 finished
# 1930 / 2800 	 finished
# 1940 / 2800 	 finished
# 1950 / 2800 	 finished
# 1960 / 2800 	 finished
# 1970 / 2800 	 finished
# 1980 / 2800 	 finished
# 1990 / 2800 	 finished
# 2000 / 2800 	 finished
# 2010 / 2800 	 finished
# 2020 / 2800 	 finished
# 2030 / 2800 	 finished
# 2040 / 2800 	 finished
# 2050 / 2800 	 finished
# 2060 / 2800 	 finished
# 2070 / 2800 	 finished
# 2080 / 2800 	 finished
# 2090 / 2800 	 finished
# 2100 / 2800 	 finished
# 2110 / 2800 	 finished
# 2120 / 2800 	 finished
# 2130 / 2800 	 finished
# 2140 / 2800 	 finished
# 2150 / 2800 	 finished
# 2160 / 2800 	 finished
# 2170 / 2800 	 finished
# 2180 / 2800 	 finished
# 2190 / 2800 	 finished
# 2200 / 2800 	 finished
# 2210 / 2800 	 finished
# 2220 / 2800 	 finished
# 2230 / 2800 	 finished
# 2240 / 2800 	 finished
# 2250 / 2800 	 finished
# 2260 / 2800 	 finished
# 2270 / 2800 	 finished
# 2280 / 2800 	 finished
# 2290 / 2800 	 finished
# 2300 / 2800 	 finished
# 2310 / 2800 	 finished
# 2320 / 2800 	 finished
# 2330 / 2800 	 finished
# 2340 / 2800 	 finished
# 2350 / 2800 	 finished
# 2360 / 2800 	 finished
# 2370 / 2800 	 finished
# 2380 / 2800 	 finished
# 2390 / 2800 	 finished
# 2400 / 2800 	 finished
# 2410 / 2800 	 finished
# 2420 / 2800 	 finished
# 2430 / 2800 	 finished
# 2440 / 2800 	 finished
# 2450 / 2800 	 finished
# 2460 / 2800 	 finished
# 2470 / 2800 	 finished
# 2480 / 2800 	 finished
# 2490 / 2800 	 finished
# 2500 / 2800 	 finished
# 2510 / 2800 	 finished
# 2520 / 2800 	 finished
# 2530 / 2800 	 finished
# 2540 / 2800 	 finished
# 2550 / 2800 	 finished
# 2560 / 2800 	 finished
# 2570 / 2800 	 finished
# 2580 / 2800 	 finished
# 2590 / 2800 	 finished
# 2600 / 2800 	 finished
# 2610 / 2800 	 finished
# 2620 / 2800 	 finished
# 2630 / 2800 	 finished
# 2640 / 2800 	 finished
# 2650 / 2800 	 finished
# 2660 / 2800 	 finished
# 2670 / 2800 	 finished
# 2680 / 2800 	 finished
# 2690 / 2800 	 finished
# 2700 / 2800 	 finished
# 2710 / 2800 	 finished
# 2720 / 2800 	 finished
# 2730 / 2800 	 finished
# 2740 / 2800 	 finished
# 2750 / 2800 	 finished
# 2760 / 2800 	 finished
# 2770 / 2800 	 finished
# 2780 / 2800 	 finished
# 2790 / 2800 	 finished
#      data size  Brier score  precision    recall        F1   profit  \
# 0        101.0   365.861999   0.529595  0.742358  0.618182 -0.05432
# 1        111.0   364.494832   0.521739  0.733624  0.609800 -0.07208
# 2        121.0   373.394863   0.518634  0.729258  0.606171 -0.06634
# 3        131.0   367.060960   0.526154  0.746725  0.617329 -0.10324
# 4        141.0   371.432250   0.531987  0.689956  0.600760 -0.11542
# ..         ...          ...        ...       ...       ...      ...
# 265     2711.0   326.211304   0.566434  0.707424  0.629126 -0.03122
# 266     2721.0   326.324144   0.570423  0.707424  0.631579 -0.03572
# 267     2731.0   326.407973   0.570423  0.707424  0.631579 -0.03292
# 268     2741.0   326.363666   0.566434  0.707424  0.629126 -0.02342
# 269     2751.0   326.487803   0.567944  0.711790  0.631783 -0.01142
#
#      modified Brier score
# 0               77.686369
# 1               74.807719
# 2               78.118018
# 3               70.809556
# 4               78.653247
# ..                    ...
# 265             42.220704
# 266             42.347627
# 267             42.340576
# 268             42.357454
# 269             42.312274
#
# [270 rows x 7 columns]

# %%
data_size.to_csv('../analysis/tables/data_size_analysis.csv')
data_size.to_pickle('../analysis/tables/data_size_analysis.pickle')
